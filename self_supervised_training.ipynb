# %% [markdown]
# ## 0) The Necessary Imports

# %%
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import random
import torch
import torchvision
from torch import nn
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image # PIL is a library to process images
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

import torchvision.datasets as datasets

import os
import time
import yaml

from google.colab import drive

# %%
drive.mount("/content/gdrive", force_remount=True) #Was used when training in COLLAB
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/proj/unlabeled_data.zip #Was used to load the training data in COLLAB, not needed after the first run in an environment
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: unlabeled_data/506940.PNG
#   inflating: unlabeled_data/506941.PNG
#   inflating: unlabeled_data/506942.PNG
#   inflating: unlabeled_data/506943.PNG
#   inflating: unlabeled_data/506944.PNG
#   inflating: unlabeled_data/506945.PNG
#   inflating: unlabeled_data/506946.PNG
#   inflating: unlabeled_data/506947.PNG
#   inflating: unlabeled_data/506948.PNG
#   inflating: unlabeled_data/506949.PNG
#   inflating: unlabeled_data/506950.PNG
#   inflating: unlabeled_data/506951.PNG
#   inflating: unlabeled_data/506952.PNG
#   inflating: unlabeled_data/506953.PNG
#   inflating: unlabeled_data/506954.PNG
#   inflating: unlabeled_data/506955.PNG
#   inflating: unlabeled_data/506956.PNG
#   inflating: unlabeled_data/506957.PNG
#   inflating: unlabeled_data/506958.PNG
#   inflating: unlabeled_data/506959.PNG
#   inflating: unlabeled_data/506960.PNG
#   inflating: unlabeled_data/506961.PNG
#   inflating: unlabeled_data/506962.PNG
#   inflating: unlabeled_data/506963.PNG
#   inflating: unlabeled_data/506964.PNG
#   inflating: unlabeled_data/506965.PNG
#   inflating: unlabeled_data/506966.PNG
#   inflating: unlabeled_data/506967.PNG
#   inflating: unlabeled_data/506968.PNG
#   inflating: unlabeled_data/506969.PNG
#   inflating: unlabeled_data/506970.PNG
#   inflating: unlabeled_data/506971.PNG
#   inflating: unlabeled_data/506972.PNG
#   inflating: unlabeled_data/506973.PNG
#   inflating: unlabeled_data/506974.PNG
#   inflating: unlabeled_data/506975.PNG
#   inflating: unlabeled_data/506976.PNG
#   inflating: unlabeled_data/506977.PNG
#   inflating: unlabeled_data/506978.PNG
#   inflating: unlabeled_data/506979.PNG
#   inflating: unlabeled_data/506980.PNG
#   inflating: unlabeled_data/506981.PNG
#   inflating: unlabeled_data/506982.PNG
#   inflating: unlabeled_data/506983.PNG
#   inflating: unlabeled_data/506984.PNG
#   inflating: unlabeled_data/506985.PNG
#   inflating: unlabeled_data/506986.PNG
#   inflating: unlabeled_data/506987.PNG
#   inflating: unlabeled_data/506988.PNG
#   inflating: unlabeled_data/506989.PNG
#   inflating: unlabeled_data/506990.PNG
#   inflating: unlabeled_data/506991.PNG
#   inflating: unlabeled_data/506992.PNG
#   inflating: unlabeled_data/506993.PNG
#   inflating: unlabeled_data/506994.PNG
#   inflating: unlabeled_data/506995.PNG
#   inflating: unlabeled_data/506996.PNG
#   inflating: unlabeled_data/506997.PNG
#   inflating: unlabeled_data/506998.PNG
#   inflating: unlabeled_data/506999.PNG
#   inflating: unlabeled_data/507000.PNG
#   inflating: unlabeled_data/507001.PNG
#   inflating: unlabeled_data/507002.PNG
#   inflating: unlabeled_data/507003.PNG
#   inflating: unlabeled_data/507004.PNG
#   inflating: unlabeled_data/507005.PNG
#   inflating: unlabeled_data/507006.PNG
#   inflating: unlabeled_data/507007.PNG
#   inflating: unlabeled_data/507008.PNG
#   inflating: unlabeled_data/507009.PNG
#   inflating: unlabeled_data/507010.PNG
#   inflating: unlabeled_data/507011.PNG
#   inflating: unlabeled_data/507012.PNG
#   inflating: unlabeled_data/507013.PNG
#   inflating: unlabeled_data/507014.PNG
#   inflating: unlabeled_data/507015.PNG
#   inflating: unlabeled_data/507016.PNG
#   inflating: unlabeled_data/507017.PNG
#   inflating: unlabeled_data/507018.PNG
#   inflating: unlabeled_data/507019.PNG
#   inflating: unlabeled_data/507020.PNG
#   inflating: unlabeled_data/507021.PNG
#   inflating: unlabeled_data/507022.PNG
#   inflating: unlabeled_data/507023.PNG
#   inflating: unlabeled_data/507024.PNG
#   inflating: unlabeled_data/507025.PNG
#   inflating: unlabeled_data/507026.PNG
#   inflating: unlabeled_data/507027.PNG
#   inflating: unlabeled_data/507028.PNG
#   inflating: unlabeled_data/507029.PNG
#   inflating: unlabeled_data/507030.PNG
#   inflating: unlabeled_data/507031.PNG
#   inflating: unlabeled_data/507032.PNG
#   inflating: unlabeled_data/507033.PNG
#   inflating: unlabeled_data/507034.PNG
#   inflating: unlabeled_data/507035.PNG
#   inflating: unlabeled_data/507036.PNG
#   inflating: unlabeled_data/507037.PNG
#   inflating: unlabeled_data/507038.PNG
#   inflating: unlabeled_data/507039.PNG
#   inflating: unlabeled_data/507040.PNG
#   inflating: unlabeled_data/507041.PNG
#   inflating: unlabeled_data/507042.PNG
#   inflating: unlabeled_data/507043.PNG
#   inflating: unlabeled_data/507044.PNG
#   inflating: unlabeled_data/507045.PNG
#   inflating: unlabeled_data/507048.PNG
#   inflating: unlabeled_data/507049.PNG
#   inflating: unlabeled_data/507050.PNG
#   inflating: unlabeled_data/507051.PNG
#   inflating: unlabeled_data/507052.PNG
#   inflating: unlabeled_data/507053.PNG
#   inflating: unlabeled_data/507054.PNG
#   inflating: unlabeled_data/507055.PNG
#   inflating: unlabeled_data/507056.PNG
#   inflating: unlabeled_data/507057.PNG
#   inflating: unlabeled_data/507058.PNG
#   inflating: unlabeled_data/507059.PNG
#   inflating: unlabeled_data/507060.PNG
#   inflating: unlabeled_data/507061.PNG
#   inflating: unlabeled_data/507062.PNG
#   inflating: unlabeled_data/507063.PNG
#   inflating: unlabeled_data/507064.PNG
#   inflating: unlabeled_data/507065.PNG
#   inflating: unlabeled_data/507066.PNG
#   inflating: unlabeled_data/507067.PNG
#   inflating: unlabeled_data/507068.PNG
#   inflating: unlabeled_data/507069.PNG
#   inflating: unlabeled_data/507070.PNG
#   inflating: unlabeled_data/507071.PNG
#   inflating: unlabeled_data/507072.PNG
#   inflating: unlabeled_data/507073.PNG
#   inflating: unlabeled_data/507074.PNG
#   inflating: unlabeled_data/507075.PNG
#   inflating: unlabeled_data/507076.PNG
#   inflating: unlabeled_data/507077.PNG
#   inflating: unlabeled_data/507078.PNG
#   inflating: unlabeled_data/507079.PNG
#   inflating: unlabeled_data/507080.PNG
#   inflating: unlabeled_data/507081.PNG
#   inflating: unlabeled_data/507082.PNG
#   inflating: unlabeled_data/507083.PNG
#   inflating: unlabeled_data/507084.PNG
#   inflating: unlabeled_data/507085.PNG
#   inflating: unlabeled_data/507086.PNG
#   inflating: unlabeled_data/507087.PNG
#   inflating: unlabeled_data/507088.PNG
#   inflating: unlabeled_data/507089.PNG
#   inflating: unlabeled_data/507090.PNG
#   inflating: unlabeled_data/507091.PNG
#   inflating: unlabeled_data/507092.PNG
#   inflating: unlabeled_data/507093.PNG
#   inflating: unlabeled_data/507094.PNG
#   inflating: unlabeled_data/507095.PNG
#   inflating: unlabeled_data/507096.PNG
#   inflating: unlabeled_data/507097.PNG
#   inflating: unlabeled_data/507098.PNG
#   inflating: unlabeled_data/507099.PNG
#   inflating: unlabeled_data/507100.PNG
#   inflating: unlabeled_data/507101.PNG
#   inflating: unlabeled_data/507102.PNG
#   inflating: unlabeled_data/507103.PNG
#   inflating: unlabeled_data/507104.PNG
#   inflating: unlabeled_data/507105.PNG
#   inflating: unlabeled_data/507106.PNG
#   inflating: unlabeled_data/507107.PNG
#   inflating: unlabeled_data/507108.PNG
#   inflating: unlabeled_data/507109.PNG
#   inflating: unlabeled_data/507110.PNG
#   inflating: unlabeled_data/507111.PNG
#   inflating: unlabeled_data/507112.PNG
#   inflating: unlabeled_data/507113.PNG
#   inflating: unlabeled_data/507114.PNG
#   inflating: unlabeled_data/507115.PNG
#   inflating: unlabeled_data/507116.PNG
#   inflating: unlabeled_data/507117.PNG
#   inflating: unlabeled_data/507118.PNG
#   inflating: unlabeled_data/507119.PNG
#   inflating: unlabeled_data/507120.PNG
#   inflating: unlabeled_data/507121.PNG
#   inflating: unlabeled_data/507122.PNG
#   inflating: unlabeled_data/507123.PNG
#   inflating: unlabeled_data/507124.PNG
#   inflating: unlabeled_data/507125.PNG
#   inflating: unlabeled_data/507126.PNG
#   inflating: unlabeled_data/507127.PNG
#   inflating: unlabeled_data/507128.PNG
#   inflating: unlabeled_data/507129.PNG
#   inflating: unlabeled_data/507130.PNG
#   inflating: unlabeled_data/507131.PNG
#   inflating: unlabeled_data/507132.PNG
#   inflating: unlabeled_data/507133.PNG
#   inflating: unlabeled_data/507134.PNG
#   inflating: unlabeled_data/507135.PNG
#   inflating: unlabeled_data/507136.PNG
#   inflating: unlabeled_data/507137.PNG
#   inflating: unlabeled_data/507138.PNG
#   inflating: unlabeled_data/507139.PNG
#   inflating: unlabeled_data/507140.PNG
#   inflating: unlabeled_data/507141.PNG
#   inflating: unlabeled_data/507142.PNG
#   inflating: unlabeled_data/507143.PNG
#   inflating: unlabeled_data/507144.PNG
#   inflating: unlabeled_data/507145.PNG
#   inflating: unlabeled_data/507146.PNG
#   inflating: unlabeled_data/507147.PNG
#   inflating: unlabeled_data/507148.PNG
#   inflating: unlabeled_data/507149.PNG
#   inflating: unlabeled_data/507150.PNG
#   inflating: unlabeled_data/507151.PNG
#   inflating: unlabeled_data/507152.PNG
#   inflating: unlabeled_data/507153.PNG
#   inflating: unlabeled_data/507154.PNG
#   inflating: unlabeled_data/507155.PNG
#   inflating: unlabeled_data/507156.PNG
#   inflating: unlabeled_data/507157.PNG
#   inflating: unlabeled_data/507158.PNG
#   inflating: unlabeled_data/507159.PNG
#   inflating: unlabeled_data/507160.PNG
#   inflating: unlabeled_data/507161.PNG
#   inflating: unlabeled_data/507162.PNG
#   inflating: unlabeled_data/507163.PNG
#   inflating: unlabeled_data/507164.PNG
#   inflating: unlabeled_data/507165.PNG
#   inflating: unlabeled_data/507166.PNG
#   inflating: unlabeled_data/507167.PNG
#   inflating: unlabeled_data/507168.PNG
#   inflating: unlabeled_data/507169.PNG
#   inflating: unlabeled_data/507170.PNG
#   inflating: unlabeled_data/507171.PNG
#   inflating: unlabeled_data/507172.PNG
#   inflating: unlabeled_data/507173.PNG
#   inflating: unlabeled_data/507174.PNG
#   inflating: unlabeled_data/507175.PNG
#   inflating: unlabeled_data/507176.PNG
#   inflating: unlabeled_data/507177.PNG
#   inflating: unlabeled_data/507178.PNG
#   inflating: unlabeled_data/507179.PNG
#   inflating: unlabeled_data/507180.PNG
#   inflating: unlabeled_data/507181.PNG
#   inflating: unlabeled_data/507182.PNG
#   inflating: unlabeled_data/507183.PNG
#   inflating: unlabeled_data/507184.PNG
#   inflating: unlabeled_data/507185.PNG
#   inflating: unlabeled_data/507186.PNG
#   inflating: unlabeled_data/507187.PNG
#   inflating: unlabeled_data/507188.PNG
#   inflating: unlabeled_data/507189.PNG
#   inflating: unlabeled_data/507190.PNG
#   inflating: unlabeled_data/507191.PNG
#   inflating: unlabeled_data/507192.PNG
#   inflating: unlabeled_data/507193.PNG
#   inflating: unlabeled_data/507194.PNG
#   inflating: unlabeled_data/507195.PNG
#   inflating: unlabeled_data/507196.PNG
#   inflating: unlabeled_data/507197.PNG
#   inflating: unlabeled_data/507198.PNG
#   inflating: unlabeled_data/507199.PNG
#   inflating: unlabeled_data/507200.PNG
#   inflating: unlabeled_data/507201.PNG
#   inflating: unlabeled_data/507202.PNG
#   inflating: unlabeled_data/507203.PNG
#   inflating: unlabeled_data/507204.PNG
#   inflating: unlabeled_data/507205.PNG
#   inflating: unlabeled_data/507206.PNG
#   inflating: unlabeled_data/507207.PNG
#   inflating: unlabeled_data/507208.PNG
#   inflating: unlabeled_data/507209.PNG
#   inflating: unlabeled_data/507210.PNG
#   inflating: unlabeled_data/507211.PNG
#   inflating: unlabeled_data/507212.PNG
#   inflating: unlabeled_data/507213.PNG
#   inflating: unlabeled_data/507214.PNG
#   inflating: unlabeled_data/507215.PNG
#   inflating: unlabeled_data/507218.PNG
#   inflating: unlabeled_data/507219.PNG
#   inflating: unlabeled_data/507220.PNG
#   inflating: unlabeled_data/507221.PNG
#   inflating: unlabeled_data/507222.PNG
#   inflating: unlabeled_data/507223.PNG
#   inflating: unlabeled_data/507224.PNG
#   inflating: unlabeled_data/507225.PNG
#   inflating: unlabeled_data/507226.PNG
#   inflating: unlabeled_data/507227.PNG
#   inflating: unlabeled_data/507228.PNG
#   inflating: unlabeled_data/507229.PNG
#   inflating: unlabeled_data/507230.PNG
#   inflating: unlabeled_data/507231.PNG
#   inflating: unlabeled_data/507232.PNG
#   inflating: unlabeled_data/507233.PNG
#   inflating: unlabeled_data/507234.PNG
#   inflating: unlabeled_data/507235.PNG
#   inflating: unlabeled_data/507236.PNG
#   inflating: unlabeled_data/507237.PNG
#   inflating: unlabeled_data/507238.PNG
#   inflating: unlabeled_data/507239.PNG
#   inflating: unlabeled_data/507240.PNG
#  extracting: unlabeled_data/507241.PNG
#   inflating: unlabeled_data/507242.PNG
#   inflating: unlabeled_data/507243.PNG
#   inflating: unlabeled_data/507244.PNG
#   inflating: unlabeled_data/507245.PNG
#   inflating: unlabeled_data/507246.PNG
#   inflating: unlabeled_data/507247.PNG
#   inflating: unlabeled_data/507248.PNG
#   inflating: unlabeled_data/507249.PNG
#   inflating: unlabeled_data/507250.PNG
#   inflating: unlabeled_data/507251.PNG
#   inflating: unlabeled_data/507252.PNG
#   inflating: unlabeled_data/507253.PNG
#   inflating: unlabeled_data/507254.PNG
#   inflating: unlabeled_data/507255.PNG
#   inflating: unlabeled_data/507256.PNG
#   inflating: unlabeled_data/507257.PNG
#   inflating: unlabeled_data/507258.PNG
#   inflating: unlabeled_data/507259.PNG
#   inflating: unlabeled_data/507260.PNG
#   inflating: unlabeled_data/507261.PNG
#   inflating: unlabeled_data/507262.PNG
#   inflating: unlabeled_data/507263.PNG
#   inflating: unlabeled_data/507264.PNG
#   inflating: unlabeled_data/507265.PNG
#   inflating: unlabeled_data/507266.PNG
#   inflating: unlabeled_data/507267.PNG
#   inflating: unlabeled_data/507268.PNG
#   inflating: unlabeled_data/507269.PNG
#   inflating: unlabeled_data/507270.PNG
#   inflating: unlabeled_data/507271.PNG
#   inflating: unlabeled_data/507272.PNG
#   inflating: unlabeled_data/507273.PNG
#   inflating: unlabeled_data/507274.PNG
#   inflating: unlabeled_data/507275.PNG
#   inflating: unlabeled_data/507276.PNG
#   inflating: unlabeled_data/507277.PNG
#   inflating: unlabeled_data/507278.PNG
#   inflating: unlabeled_data/507279.PNG
#   inflating: unlabeled_data/507280.PNG
#   inflating: unlabeled_data/507281.PNG
#   inflating: unlabeled_data/507282.PNG
#   inflating: unlabeled_data/507283.PNG
#   inflating: unlabeled_data/507284.PNG
#   inflating: unlabeled_data/507285.PNG
#   inflating: unlabeled_data/507286.PNG
#   inflating: unlabeled_data/507287.PNG
#   inflating: unlabeled_data/507288.PNG
#   inflating: unlabeled_data/507289.PNG
#   inflating: unlabeled_data/507290.PNG
#   inflating: unlabeled_data/507291.PNG
#   inflating: unlabeled_data/507292.PNG
#   inflating: unlabeled_data/507293.PNG
#   inflating: unlabeled_data/507294.PNG
#   inflating: unlabeled_data/507295.PNG
#   inflating: unlabeled_data/507296.PNG
#   inflating: unlabeled_data/507297.PNG
#   inflating: unlabeled_data/507298.PNG
#   inflating: unlabeled_data/507299.PNG
#   inflating: unlabeled_data/507300.PNG
#   inflating: unlabeled_data/507301.PNG
#   inflating: unlabeled_data/507302.PNG
#   inflating: unlabeled_data/507303.PNG
#   inflating: unlabeled_data/507304.PNG
#   inflating: unlabeled_data/507305.PNG
#   inflating: unlabeled_data/507306.PNG
#   inflating: unlabeled_data/507307.PNG
#   inflating: unlabeled_data/507308.PNG
#   inflating: unlabeled_data/507309.PNG
#   inflating: unlabeled_data/507310.PNG
#   inflating: unlabeled_data/507311.PNG
#   inflating: unlabeled_data/507312.PNG
#   inflating: unlabeled_data/507313.PNG
#   inflating: unlabeled_data/507314.PNG
#   inflating: unlabeled_data/507315.PNG
#   inflating: unlabeled_data/507316.PNG
#   inflating: unlabeled_data/507317.PNG
#   inflating: unlabeled_data/507318.PNG
#   inflating: unlabeled_data/507319.PNG
#   inflating: unlabeled_data/507320.PNG
#   inflating: unlabeled_data/507321.PNG
#   inflating: unlabeled_data/507322.PNG
#   inflating: unlabeled_data/507323.PNG
#   inflating: unlabeled_data/507324.PNG
#   inflating: unlabeled_data/507325.PNG
#   inflating: unlabeled_data/507326.PNG
#   inflating: unlabeled_data/507327.PNG
#   inflating: unlabeled_data/507328.PNG
#   inflating: unlabeled_data/507329.PNG
#   inflating: unlabeled_data/507330.PNG
#   inflating: unlabeled_data/507331.PNG
#   inflating: unlabeled_data/507332.PNG
#   inflating: unlabeled_data/507333.PNG
#   inflating: unlabeled_data/507334.PNG
#   inflating: unlabeled_data/507335.PNG
#   inflating: unlabeled_data/507336.PNG
#   inflating: unlabeled_data/507337.PNG
#   inflating: unlabeled_data/507338.PNG
#   inflating: unlabeled_data/507339.PNG
#   inflating: unlabeled_data/507340.PNG
#   inflating: unlabeled_data/507341.PNG
#   inflating: unlabeled_data/507342.PNG
#   inflating: unlabeled_data/507343.PNG
#   inflating: unlabeled_data/507344.PNG
#   inflating: unlabeled_data/507345.PNG
#   inflating: unlabeled_data/507346.PNG
#   inflating: unlabeled_data/507347.PNG
#   inflating: unlabeled_data/507348.PNG
#   inflating: unlabeled_data/507349.PNG
#   inflating: unlabeled_data/507350.PNG
#   inflating: unlabeled_data/507351.PNG
#   inflating: unlabeled_data/507352.PNG
#   inflating: unlabeled_data/507353.PNG
#   inflating: unlabeled_data/507354.PNG
#   inflating: unlabeled_data/507355.PNG
#   inflating: unlabeled_data/507356.PNG
#   inflating: unlabeled_data/507357.PNG
#   inflating: unlabeled_data/507358.PNG
#   inflating: unlabeled_data/507359.PNG
#   inflating: unlabeled_data/507360.PNG
#   inflating: unlabeled_data/507361.PNG
#   inflating: unlabeled_data/507362.PNG
#   inflating: unlabeled_data/507363.PNG
#   inflating: unlabeled_data/507364.PNG
#   inflating: unlabeled_data/507365.PNG
#   inflating: unlabeled_data/507366.PNG
#   inflating: unlabeled_data/507367.PNG
#   inflating: unlabeled_data/507368.PNG
#   inflating: unlabeled_data/507369.PNG
#   inflating: unlabeled_data/507370.PNG
#   inflating: unlabeled_data/507371.PNG
#   inflating: unlabeled_data/507372.PNG
#   inflating: unlabeled_data/507373.PNG
#   inflating: unlabeled_data/507374.PNG
#   inflating: unlabeled_data/507375.PNG
#   inflating: unlabeled_data/507376.PNG
#   inflating: unlabeled_data/507377.PNG
#   inflating: unlabeled_data/507378.PNG
#   inflating: unlabeled_data/507379.PNG
#   inflating: unlabeled_data/507380.PNG
#   inflating: unlabeled_data/507381.PNG
#   inflating: unlabeled_data/507382.PNG
#   inflating: unlabeled_data/507383.PNG
#   inflating: unlabeled_data/507384.PNG
#   inflating: unlabeled_data/507385.PNG
#   inflating: unlabeled_data/507388.PNG
#   inflating: unlabeled_data/507389.PNG
#   inflating: unlabeled_data/507390.PNG
#   inflating: unlabeled_data/507391.PNG
#   inflating: unlabeled_data/507392.PNG
#   inflating: unlabeled_data/507393.PNG
#   inflating: unlabeled_data/507394.PNG
#   inflating: unlabeled_data/507395.PNG
#   inflating: unlabeled_data/507396.PNG
#   inflating: unlabeled_data/507397.PNG
#   inflating: unlabeled_data/507398.PNG
#   inflating: unlabeled_data/507399.PNG
#   inflating: unlabeled_data/507400.PNG
#   inflating: unlabeled_data/507401.PNG
#   inflating: unlabeled_data/507402.PNG
#   inflating: unlabeled_data/507403.PNG
#   inflating: unlabeled_data/507404.PNG
#   inflating: unlabeled_data/507405.PNG
#   inflating: unlabeled_data/507406.PNG
#   inflating: unlabeled_data/507407.PNG
#   inflating: unlabeled_data/507408.PNG
#   inflating: unlabeled_data/507409.PNG
#   inflating: unlabeled_data/507410.PNG
#   inflating: unlabeled_data/507411.PNG
#   inflating: unlabeled_data/507412.PNG
#   inflating: unlabeled_data/507413.PNG
#   inflating: unlabeled_data/507414.PNG
#   inflating: unlabeled_data/507415.PNG
#   inflating: unlabeled_data/507416.PNG
#   inflating: unlabeled_data/507417.PNG
#   inflating: unlabeled_data/507418.PNG
#   inflating: unlabeled_data/507419.PNG
#   inflating: unlabeled_data/507420.PNG
#   inflating: unlabeled_data/507421.PNG
#   inflating: unlabeled_data/507422.PNG
#   inflating: unlabeled_data/507423.PNG
#   inflating: unlabeled_data/507424.PNG
#   inflating: unlabeled_data/507425.PNG
#   inflating: unlabeled_data/507426.PNG
#   inflating: unlabeled_data/507427.PNG
#   inflating: unlabeled_data/507428.PNG
#   inflating: unlabeled_data/507429.PNG
#   inflating: unlabeled_data/507430.PNG
#   inflating: unlabeled_data/507431.PNG
#   inflating: unlabeled_data/507432.PNG
#   inflating: unlabeled_data/507433.PNG
#   inflating: unlabeled_data/507434.PNG
#   inflating: unlabeled_data/507435.PNG
#   inflating: unlabeled_data/507436.PNG
#   inflating: unlabeled_data/507437.PNG
#   inflating: unlabeled_data/507438.PNG
#   inflating: unlabeled_data/507439.PNG
#   inflating: unlabeled_data/507440.PNG
#   inflating: unlabeled_data/507441.PNG
#   inflating: unlabeled_data/507442.PNG
#   inflating: unlabeled_data/507443.PNG
#   inflating: unlabeled_data/507444.PNG
#   inflating: unlabeled_data/507445.PNG
#   inflating: unlabeled_data/507446.PNG
#   inflating: unlabeled_data/507447.PNG
#   inflating: unlabeled_data/507448.PNG
#   inflating: unlabeled_data/507449.PNG
#   inflating: unlabeled_data/507450.PNG
#   inflating: unlabeled_data/507451.PNG
#   inflating: unlabeled_data/507452.PNG
#   inflating: unlabeled_data/507453.PNG
#   inflating: unlabeled_data/507454.PNG
#   inflating: unlabeled_data/507455.PNG
#   inflating: unlabeled_data/507456.PNG
#   inflating: unlabeled_data/507457.PNG
#   inflating: unlabeled_data/507458.PNG
#   inflating: unlabeled_data/507459.PNG
#   inflating: unlabeled_data/507460.PNG
#   inflating: unlabeled_data/507461.PNG
#   inflating: unlabeled_data/507462.PNG
#   inflating: unlabeled_data/507463.PNG
#   inflating: unlabeled_data/507464.PNG
#   inflating: unlabeled_data/507465.PNG
#   inflating: unlabeled_data/507466.PNG
#   inflating: unlabeled_data/507467.PNG
#   inflating: unlabeled_data/507468.PNG
#   inflating: unlabeled_data/507469.PNG
#   inflating: unlabeled_data/507470.PNG
#   inflating: unlabeled_data/507471.PNG
#   inflating: unlabeled_data/507472.PNG
#   inflating: unlabeled_data/507473.PNG
#   inflating: unlabeled_data/507474.PNG
#   inflating: unlabeled_data/507475.PNG
#   inflating: unlabeled_data/507476.PNG
#   inflating: unlabeled_data/507477.PNG
#   inflating: unlabeled_data/507478.PNG
#   inflating: unlabeled_data/507479.PNG
#   inflating: unlabeled_data/507480.PNG
#   inflating: unlabeled_data/507481.PNG
#   inflating: unlabeled_data/507482.PNG
#   inflating: unlabeled_data/507483.PNG
#   inflating: unlabeled_data/507484.PNG
#   inflating: unlabeled_data/507485.PNG
#   inflating: unlabeled_data/507486.PNG
#   inflating: unlabeled_data/507487.PNG
#   inflating: unlabeled_data/507488.PNG
#   inflating: unlabeled_data/507489.PNG
#   inflating: unlabeled_data/507490.PNG
#   inflating: unlabeled_data/507491.PNG
#   inflating: unlabeled_data/507492.PNG
#   inflating: unlabeled_data/507493.PNG
#   inflating: unlabeled_data/507494.PNG
#   inflating: unlabeled_data/507495.PNG
#   inflating: unlabeled_data/507496.PNG
#   inflating: unlabeled_data/507497.PNG
#   inflating: unlabeled_data/507498.PNG
#   inflating: unlabeled_data/507499.PNG
#   inflating: unlabeled_data/507500.PNG
#   inflating: unlabeled_data/507501.PNG
#   inflating: unlabeled_data/507502.PNG
#   inflating: unlabeled_data/507503.PNG
#   inflating: unlabeled_data/507504.PNG
#   inflating: unlabeled_data/507505.PNG
#   inflating: unlabeled_data/507506.PNG
#   inflating: unlabeled_data/507507.PNG
#   inflating: unlabeled_data/507508.PNG
#   inflating: unlabeled_data/507509.PNG
#   inflating: unlabeled_data/507510.PNG
#   inflating: unlabeled_data/507511.PNG
#   inflating: unlabeled_data/507512.PNG
#   inflating: unlabeled_data/507513.PNG
#   inflating: unlabeled_data/507514.PNG
#   inflating: unlabeled_data/507515.PNG
#   inflating: unlabeled_data/507516.PNG
#   inflating: unlabeled_data/507517.PNG
#   inflating: unlabeled_data/507518.PNG
#   inflating: unlabeled_data/507519.PNG
#   inflating: unlabeled_data/507520.PNG
#   inflating: unlabeled_data/507521.PNG
#   inflating: unlabeled_data/507522.PNG
#   inflating: unlabeled_data/507523.PNG
#   inflating: unlabeled_data/507524.PNG
#   inflating: unlabeled_data/507525.PNG
#   inflating: unlabeled_data/507526.PNG
#   inflating: unlabeled_data/507527.PNG
#   inflating: unlabeled_data/507528.PNG
#   inflating: unlabeled_data/507529.PNG
#   inflating: unlabeled_data/507530.PNG
#   inflating: unlabeled_data/507531.PNG
#   inflating: unlabeled_data/507532.PNG
#   inflating: unlabeled_data/507533.PNG
#   inflating: unlabeled_data/507534.PNG
#   inflating: unlabeled_data/507535.PNG
#   inflating: unlabeled_data/507536.PNG
#   inflating: unlabeled_data/507537.PNG
#   inflating: unlabeled_data/507538.PNG
#   inflating: unlabeled_data/507539.PNG
#   inflating: unlabeled_data/507540.PNG
#   inflating: unlabeled_data/507541.PNG
#   inflating: unlabeled_data/507542.PNG
#   inflating: unlabeled_data/507543.PNG
#   inflating: unlabeled_data/507544.PNG
#   inflating: unlabeled_data/507545.PNG
#   inflating: unlabeled_data/507546.PNG
#   inflating: unlabeled_data/507547.PNG
#   inflating: unlabeled_data/507548.PNG
#   inflating: unlabeled_data/507549.PNG
#   inflating: unlabeled_data/507550.PNG
#   inflating: unlabeled_data/507551.PNG
#   inflating: unlabeled_data/507552.PNG
#   inflating: unlabeled_data/507553.PNG
#   inflating: unlabeled_data/507554.PNG
#   inflating: unlabeled_data/507555.PNG
#   inflating: unlabeled_data/507558.PNG
#   inflating: unlabeled_data/507559.PNG
#   inflating: unlabeled_data/507560.PNG
#   inflating: unlabeled_data/507561.PNG
#   inflating: unlabeled_data/507562.PNG
#   inflating: unlabeled_data/507563.PNG
#   inflating: unlabeled_data/507564.PNG
#   inflating: unlabeled_data/507565.PNG
#   inflating: unlabeled_data/507566.PNG
#   inflating: unlabeled_data/507567.PNG
#   inflating: unlabeled_data/507568.PNG
#   inflating: unlabeled_data/507569.PNG
#   inflating: unlabeled_data/507570.PNG
#   inflating: unlabeled_data/507571.PNG
#   inflating: unlabeled_data/507572.PNG
#   inflating: unlabeled_data/507573.PNG
#   inflating: unlabeled_data/507574.PNG
#   inflating: unlabeled_data/507575.PNG
#   inflating: unlabeled_data/507576.PNG
#   inflating: unlabeled_data/507577.PNG
#   inflating: unlabeled_data/507578.PNG
#   inflating: unlabeled_data/507579.PNG
#   inflating: unlabeled_data/507580.PNG
#   inflating: unlabeled_data/507581.PNG
#   inflating: unlabeled_data/507582.PNG
#   inflating: unlabeled_data/507583.PNG
#   inflating: unlabeled_data/507584.PNG
#   inflating: unlabeled_data/507585.PNG
#   inflating: unlabeled_data/507586.PNG
#   inflating: unlabeled_data/507587.PNG
#   inflating: unlabeled_data/507588.PNG
#   inflating: unlabeled_data/507589.PNG
#   inflating: unlabeled_data/507590.PNG
#   inflating: unlabeled_data/507591.PNG
#   inflating: unlabeled_data/507592.PNG
#   inflating: unlabeled_data/507593.PNG
#   inflating: unlabeled_data/507594.PNG
#   inflating: unlabeled_data/507595.PNG
#   inflating: unlabeled_data/507596.PNG
#   inflating: unlabeled_data/507597.PNG
#   inflating: unlabeled_data/507598.PNG
#   inflating: unlabeled_data/507599.PNG
#   inflating: unlabeled_data/507600.PNG
#   inflating: unlabeled_data/507601.PNG
#   inflating: unlabeled_data/507602.PNG
#   inflating: unlabeled_data/507603.PNG
#   inflating: unlabeled_data/507604.PNG
#   inflating: unlabeled_data/507605.PNG
#   inflating: unlabeled_data/507606.PNG
#   inflating: unlabeled_data/507607.PNG
#   inflating: unlabeled_data/507608.PNG
#   inflating: unlabeled_data/507609.PNG
#   inflating: unlabeled_data/507610.PNG
#   inflating: unlabeled_data/507611.PNG
#   inflating: unlabeled_data/507612.PNG
#   inflating: unlabeled_data/507613.PNG
#   inflating: unlabeled_data/507614.PNG
#   inflating: unlabeled_data/507615.PNG
#   inflating: unlabeled_data/507616.PNG
#   inflating: unlabeled_data/507617.PNG
#   inflating: unlabeled_data/507618.PNG
#   inflating: unlabeled_data/507619.PNG
#   inflating: unlabeled_data/507620.PNG
#   inflating: unlabeled_data/507621.PNG
#   inflating: unlabeled_data/507622.PNG
#   inflating: unlabeled_data/507623.PNG
#   inflating: unlabeled_data/507624.PNG
#   inflating: unlabeled_data/507625.PNG
#   inflating: unlabeled_data/507626.PNG
#   inflating: unlabeled_data/507627.PNG
#   inflating: unlabeled_data/507628.PNG
#   inflating: unlabeled_data/507629.PNG
#   inflating: unlabeled_data/507630.PNG
#   inflating: unlabeled_data/507631.PNG
#   inflating: unlabeled_data/507632.PNG
#   inflating: unlabeled_data/507633.PNG
#   inflating: unlabeled_data/507634.PNG
#   inflating: unlabeled_data/507635.PNG
#   inflating: unlabeled_data/507636.PNG
#   inflating: unlabeled_data/507637.PNG
#   inflating: unlabeled_data/507638.PNG
#   inflating: unlabeled_data/507639.PNG
#   inflating: unlabeled_data/507640.PNG
#   inflating: unlabeled_data/507641.PNG
#   inflating: unlabeled_data/507642.PNG
#   inflating: unlabeled_data/507643.PNG
#   inflating: unlabeled_data/507644.PNG
#   inflating: unlabeled_data/507645.PNG
#   inflating: unlabeled_data/507646.PNG
#   inflating: unlabeled_data/507647.PNG
#   inflating: unlabeled_data/507648.PNG
#   inflating: unlabeled_data/507649.PNG
#   inflating: unlabeled_data/507650.PNG
#   inflating: unlabeled_data/507651.PNG
#   inflating: unlabeled_data/507652.PNG
#   inflating: unlabeled_data/507653.PNG
#   inflating: unlabeled_data/507654.PNG
#   inflating: unlabeled_data/507655.PNG
#   inflating: unlabeled_data/507656.PNG
#   inflating: unlabeled_data/507657.PNG
#   inflating: unlabeled_data/507658.PNG
#   inflating: unlabeled_data/507659.PNG
#   inflating: unlabeled_data/507660.PNG
#   inflating: unlabeled_data/507661.PNG
#   inflating: unlabeled_data/507662.PNG
#   inflating: unlabeled_data/507663.PNG
#   inflating: unlabeled_data/507664.PNG
#   inflating: unlabeled_data/507665.PNG
#   inflating: unlabeled_data/507666.PNG
#   inflating: unlabeled_data/507667.PNG
#   inflating: unlabeled_data/507668.PNG
#   inflating: unlabeled_data/507669.PNG
#   inflating: unlabeled_data/507670.PNG
#   inflating: unlabeled_data/507671.PNG
#   inflating: unlabeled_data/507672.PNG
#   inflating: unlabeled_data/507673.PNG
#   inflating: unlabeled_data/507674.PNG
#   inflating: unlabeled_data/507675.PNG
#   inflating: unlabeled_data/507676.PNG
#   inflating: unlabeled_data/507677.PNG
#   inflating: unlabeled_data/507678.PNG
#   inflating: unlabeled_data/507679.PNG
#   inflating: unlabeled_data/507680.PNG
#   inflating: unlabeled_data/507681.PNG
#   inflating: unlabeled_data/507682.PNG
#   inflating: unlabeled_data/507683.PNG
#   inflating: unlabeled_data/507684.PNG
#   inflating: unlabeled_data/507685.PNG
#   inflating: unlabeled_data/507686.PNG
#   inflating: unlabeled_data/507687.PNG
#   inflating: unlabeled_data/507688.PNG
#   inflating: unlabeled_data/507689.PNG
#   inflating: unlabeled_data/507690.PNG
#   inflating: unlabeled_data/507691.PNG
#   inflating: unlabeled_data/507692.PNG
#   inflating: unlabeled_data/507693.PNG
#   inflating: unlabeled_data/507694.PNG
#   inflating: unlabeled_data/507695.PNG
#   inflating: unlabeled_data/507696.PNG
#   inflating: unlabeled_data/507697.PNG
#   inflating: unlabeled_data/507698.PNG
#   inflating: unlabeled_data/507699.PNG
#   inflating: unlabeled_data/507700.PNG
#   inflating: unlabeled_data/507701.PNG
#   inflating: unlabeled_data/507702.PNG
#   inflating: unlabeled_data/507703.PNG
#   inflating: unlabeled_data/507704.PNG
#   inflating: unlabeled_data/507705.PNG
#   inflating: unlabeled_data/507706.PNG
#   inflating: unlabeled_data/507707.PNG
#   inflating: unlabeled_data/507708.PNG
#   inflating: unlabeled_data/507709.PNG
#   inflating: unlabeled_data/507710.PNG
#   inflating: unlabeled_data/507711.PNG
#   inflating: unlabeled_data/507712.PNG
#   inflating: unlabeled_data/507713.PNG
#   inflating: unlabeled_data/507714.PNG
#   inflating: unlabeled_data/507715.PNG
#   inflating: unlabeled_data/507716.PNG
#   inflating: unlabeled_data/507717.PNG
#   inflating: unlabeled_data/507718.PNG
#   inflating: unlabeled_data/507719.PNG
#   inflating: unlabeled_data/507720.PNG
#   inflating: unlabeled_data/507721.PNG
#   inflating: unlabeled_data/507722.PNG
#   inflating: unlabeled_data/507723.PNG
#   inflating: unlabeled_data/507724.PNG
#   inflating: unlabeled_data/507725.PNG
#   inflating: unlabeled_data/507728.PNG
#   inflating: unlabeled_data/507729.PNG
#   inflating: unlabeled_data/507730.PNG
#   inflating: unlabeled_data/507731.PNG
#   inflating: unlabeled_data/507732.PNG
#   inflating: unlabeled_data/507733.PNG
#   inflating: unlabeled_data/507734.PNG
#   inflating: unlabeled_data/507735.PNG
#   inflating: unlabeled_data/507736.PNG
#   inflating: unlabeled_data/507737.PNG
#   inflating: unlabeled_data/507738.PNG
#   inflating: unlabeled_data/507739.PNG
#   inflating: unlabeled_data/507740.PNG
#   inflating: unlabeled_data/507741.PNG
#   inflating: unlabeled_data/507742.PNG
#   inflating: unlabeled_data/507743.PNG
#   inflating: unlabeled_data/507744.PNG
#   inflating: unlabeled_data/507745.PNG
#   inflating: unlabeled_data/507746.PNG
#   inflating: unlabeled_data/507747.PNG
#   inflating: unlabeled_data/507748.PNG
#   inflating: unlabeled_data/507749.PNG
#   inflating: unlabeled_data/507750.PNG
#   inflating: unlabeled_data/507751.PNG
#   inflating: unlabeled_data/507752.PNG
#   inflating: unlabeled_data/507753.PNG
#   inflating: unlabeled_data/507754.PNG
#   inflating: unlabeled_data/507755.PNG
#   inflating: unlabeled_data/507756.PNG
#   inflating: unlabeled_data/507757.PNG
#   inflating: unlabeled_data/507758.PNG
#   inflating: unlabeled_data/507759.PNG
#   inflating: unlabeled_data/507760.PNG
#   inflating: unlabeled_data/507761.PNG
#   inflating: unlabeled_data/507762.PNG
#   inflating: unlabeled_data/507763.PNG
#   inflating: unlabeled_data/507764.PNG
#   inflating: unlabeled_data/507765.PNG
#   inflating: unlabeled_data/507766.PNG
#   inflating: unlabeled_data/507767.PNG
#   inflating: unlabeled_data/507768.PNG
#   inflating: unlabeled_data/507769.PNG
#   inflating: unlabeled_data/507770.PNG
#   inflating: unlabeled_data/507771.PNG
#   inflating: unlabeled_data/507772.PNG
#   inflating: unlabeled_data/507773.PNG
#   inflating: unlabeled_data/507774.PNG
#   inflating: unlabeled_data/507775.PNG
#   inflating: unlabeled_data/507776.PNG
#   inflating: unlabeled_data/507777.PNG
#   inflating: unlabeled_data/507778.PNG
#   inflating: unlabeled_data/507779.PNG
#   inflating: unlabeled_data/507780.PNG
#   inflating: unlabeled_data/507781.PNG
#   inflating: unlabeled_data/507782.PNG
#   inflating: unlabeled_data/507783.PNG
#   inflating: unlabeled_data/507784.PNG
#   inflating: unlabeled_data/507785.PNG
#   inflating: unlabeled_data/507786.PNG
#   inflating: unlabeled_data/507787.PNG
#   inflating: unlabeled_data/507788.PNG
#   inflating: unlabeled_data/507789.PNG
#   inflating: unlabeled_data/507790.PNG
#   inflating: unlabeled_data/507791.PNG
#   inflating: unlabeled_data/507792.PNG
#   inflating: unlabeled_data/507793.PNG
#   inflating: unlabeled_data/507794.PNG
#   inflating: unlabeled_data/507795.PNG
#   inflating: unlabeled_data/507796.PNG
#   inflating: unlabeled_data/507797.PNG
#   inflating: unlabeled_data/507798.PNG
#   inflating: unlabeled_data/507799.PNG
#   inflating: unlabeled_data/507800.PNG
#   inflating: unlabeled_data/507801.PNG
#   inflating: unlabeled_data/507802.PNG
#   inflating: unlabeled_data/507803.PNG
#   inflating: unlabeled_data/507804.PNG
#   inflating: unlabeled_data/507805.PNG
#   inflating: unlabeled_data/507806.PNG
#   inflating: unlabeled_data/507807.PNG
#   inflating: unlabeled_data/507808.PNG
#   inflating: unlabeled_data/507809.PNG
#   inflating: unlabeled_data/507810.PNG
#   inflating: unlabeled_data/507811.PNG
#   inflating: unlabeled_data/507812.PNG
#   inflating: unlabeled_data/507813.PNG
#   inflating: unlabeled_data/507814.PNG
#   inflating: unlabeled_data/507815.PNG
#   inflating: unlabeled_data/507816.PNG
#   inflating: unlabeled_data/507817.PNG
#   inflating: unlabeled_data/507818.PNG
#   inflating: unlabeled_data/507819.PNG
#   inflating: unlabeled_data/507820.PNG
#   inflating: unlabeled_data/507821.PNG
#   inflating: unlabeled_data/507822.PNG
#   inflating: unlabeled_data/507823.PNG
#   inflating: unlabeled_data/507824.PNG
#   inflating: unlabeled_data/507825.PNG
#   inflating: unlabeled_data/507826.PNG
#   inflating: unlabeled_data/507827.PNG
#   inflating: unlabeled_data/507828.PNG
#   inflating: unlabeled_data/507829.PNG
#   inflating: unlabeled_data/507830.PNG
#   inflating: unlabeled_data/507831.PNG
#   inflating: unlabeled_data/507832.PNG
#   inflating: unlabeled_data/507833.PNG
#   inflating: unlabeled_data/507834.PNG
#   inflating: unlabeled_data/507835.PNG
#   inflating: unlabeled_data/507836.PNG
#   inflating: unlabeled_data/507837.PNG
#   inflating: unlabeled_data/507838.PNG
#   inflating: unlabeled_data/507839.PNG
#   inflating: unlabeled_data/507840.PNG
#   inflating: unlabeled_data/507841.PNG
#   inflating: unlabeled_data/507842.PNG
#   inflating: unlabeled_data/507843.PNG
#   inflating: unlabeled_data/507844.PNG
#   inflating: unlabeled_data/507845.PNG
#   inflating: unlabeled_data/507846.PNG
#   inflating: unlabeled_data/507847.PNG
#   inflating: unlabeled_data/507848.PNG
#   inflating: unlabeled_data/507849.PNG
#   inflating: unlabeled_data/507850.PNG
#   inflating: unlabeled_data/507851.PNG
#   inflating: unlabeled_data/507852.PNG
#   inflating: unlabeled_data/507853.PNG
#   inflating: unlabeled_data/507854.PNG
#   inflating: unlabeled_data/507855.PNG
#   inflating: unlabeled_data/507856.PNG
#   inflating: unlabeled_data/507857.PNG
#   inflating: unlabeled_data/507858.PNG
#   inflating: unlabeled_data/507859.PNG
#   inflating: unlabeled_data/507860.PNG
#   inflating: unlabeled_data/507861.PNG
#   inflating: unlabeled_data/507862.PNG
#   inflating: unlabeled_data/507863.PNG
#   inflating: unlabeled_data/507864.PNG
#   inflating: unlabeled_data/507865.PNG
#   inflating: unlabeled_data/507866.PNG
#   inflating: unlabeled_data/507867.PNG
#   inflating: unlabeled_data/507868.PNG
#   inflating: unlabeled_data/507869.PNG
#   inflating: unlabeled_data/507870.PNG
#   inflating: unlabeled_data/507871.PNG
#   inflating: unlabeled_data/507872.PNG
#   inflating: unlabeled_data/507873.PNG
#   inflating: unlabeled_data/507874.PNG
#   inflating: unlabeled_data/507875.PNG
#   inflating: unlabeled_data/507876.PNG
#   inflating: unlabeled_data/507877.PNG
#   inflating: unlabeled_data/507878.PNG
#   inflating: unlabeled_data/507879.PNG
#   inflating: unlabeled_data/507880.PNG
#   inflating: unlabeled_data/507881.PNG
#   inflating: unlabeled_data/507882.PNG
#   inflating: unlabeled_data/507883.PNG
#   inflating: unlabeled_data/507884.PNG
#   inflating: unlabeled_data/507885.PNG
#   inflating: unlabeled_data/507886.PNG
#   inflating: unlabeled_data/507887.PNG
#   inflating: unlabeled_data/507888.PNG
#   inflating: unlabeled_data/507889.PNG
#   inflating: unlabeled_data/507890.PNG
#   inflating: unlabeled_data/507891.PNG
#   inflating: unlabeled_data/507892.PNG
#   inflating: unlabeled_data/507893.PNG
#   inflating: unlabeled_data/507894.PNG
#   inflating: unlabeled_data/507895.PNG
#   inflating: unlabeled_data/507898.PNG
#   inflating: unlabeled_data/507899.PNG
#   inflating: unlabeled_data/507900.PNG
#   inflating: unlabeled_data/507901.PNG
#   inflating: unlabeled_data/507902.PNG
#   inflating: unlabeled_data/507903.PNG
#   inflating: unlabeled_data/507904.PNG
#   inflating: unlabeled_data/507905.PNG
#   inflating: unlabeled_data/507906.PNG
#   inflating: unlabeled_data/507907.PNG
#   inflating: unlabeled_data/507908.PNG
#   inflating: unlabeled_data/507909.PNG
#   inflating: unlabeled_data/507910.PNG
#   inflating: unlabeled_data/507911.PNG
#   inflating: unlabeled_data/507912.PNG
#   inflating: unlabeled_data/507913.PNG
#   inflating: unlabeled_data/507914.PNG
#   inflating: unlabeled_data/507915.PNG
#   inflating: unlabeled_data/507916.PNG
#   inflating: unlabeled_data/507917.PNG
#   inflating: unlabeled_data/507918.PNG
#   inflating: unlabeled_data/507919.PNG
#   inflating: unlabeled_data/507920.PNG
#   inflating: unlabeled_data/507921.PNG
#   inflating: unlabeled_data/507922.PNG
#   inflating: unlabeled_data/507923.PNG
#   inflating: unlabeled_data/507924.PNG
#   inflating: unlabeled_data/507925.PNG
#   inflating: unlabeled_data/507926.PNG
#   inflating: unlabeled_data/507927.PNG
#   inflating: unlabeled_data/507928.PNG
#   inflating: unlabeled_data/507929.PNG
#   inflating: unlabeled_data/507930.PNG
#   inflating: unlabeled_data/507931.PNG
#   inflating: unlabeled_data/507932.PNG
#   inflating: unlabeled_data/507933.PNG
#   inflating: unlabeled_data/507934.PNG
#   inflating: unlabeled_data/507935.PNG
#   inflating: unlabeled_data/507936.PNG
#   inflating: unlabeled_data/507937.PNG
#   inflating: unlabeled_data/507938.PNG
#   inflating: unlabeled_data/507939.PNG
#   inflating: unlabeled_data/507940.PNG
#   inflating: unlabeled_data/507941.PNG
#   inflating: unlabeled_data/507942.PNG
#   inflating: unlabeled_data/507943.PNG
#   inflating: unlabeled_data/507944.PNG
#   inflating: unlabeled_data/507945.PNG
#   inflating: unlabeled_data/507946.PNG
#   inflating: unlabeled_data/507947.PNG
#   inflating: unlabeled_data/507948.PNG
#   inflating: unlabeled_data/507949.PNG
#   inflating: unlabeled_data/507950.PNG
#   inflating: unlabeled_data/507951.PNG
#   inflating: unlabeled_data/507952.PNG
#   inflating: unlabeled_data/507953.PNG
#   inflating: unlabeled_data/507954.PNG
#   inflating: unlabeled_data/507955.PNG
#   inflating: unlabeled_data/507956.PNG
#   inflating: unlabeled_data/507957.PNG
#   inflating: unlabeled_data/507958.PNG
#   inflating: unlabeled_data/507959.PNG
#   inflating: unlabeled_data/507960.PNG
#   inflating: unlabeled_data/507961.PNG
#   inflating: unlabeled_data/507962.PNG
#   inflating: unlabeled_data/507963.PNG
#   inflating: unlabeled_data/507964.PNG
#   inflating: unlabeled_data/507965.PNG
#   inflating: unlabeled_data/507966.PNG
#   inflating: unlabeled_data/507967.PNG
#   inflating: unlabeled_data/507968.PNG
#   inflating: unlabeled_data/507969.PNG
#   inflating: unlabeled_data/507970.PNG
#   inflating: unlabeled_data/507971.PNG
#   inflating: unlabeled_data/507972.PNG
#   inflating: unlabeled_data/507973.PNG
#   inflating: unlabeled_data/507974.PNG
#   inflating: unlabeled_data/507975.PNG
#   inflating: unlabeled_data/507976.PNG
#   inflating: unlabeled_data/507977.PNG
#   inflating: unlabeled_data/507978.PNG
#   inflating: unlabeled_data/507979.PNG
#   inflating: unlabeled_data/507980.PNG
#   inflating: unlabeled_data/507981.PNG
#   inflating: unlabeled_data/507982.PNG
#   inflating: unlabeled_data/507983.PNG
#   inflating: unlabeled_data/507984.PNG
#   inflating: unlabeled_data/507985.PNG
#   inflating: unlabeled_data/507986.PNG
#   inflating: unlabeled_data/507987.PNG
#   inflating: unlabeled_data/507988.PNG
#   inflating: unlabeled_data/507989.PNG
#   inflating: unlabeled_data/507990.PNG
#   inflating: unlabeled_data/507991.PNG
#   inflating: unlabeled_data/507992.PNG
#   inflating: unlabeled_data/507993.PNG
#   inflating: unlabeled_data/507994.PNG
#   inflating: unlabeled_data/507995.PNG
#   inflating: unlabeled_data/507996.PNG
#   inflating: unlabeled_data/507997.PNG
#   inflating: unlabeled_data/507998.PNG
#   inflating: unlabeled_data/507999.PNG
#   inflating: unlabeled_data/508000.PNG
#   inflating: unlabeled_data/508001.PNG
#   inflating: unlabeled_data/508002.PNG
#   inflating: unlabeled_data/508003.PNG
#   inflating: unlabeled_data/508004.PNG
#   inflating: unlabeled_data/508005.PNG
#   inflating: unlabeled_data/508006.PNG
#   inflating: unlabeled_data/508007.PNG
#   inflating: unlabeled_data/508008.PNG
#   inflating: unlabeled_data/508009.PNG
#   inflating: unlabeled_data/508010.PNG
#   inflating: unlabeled_data/508011.PNG
#   inflating: unlabeled_data/508012.PNG
#   inflating: unlabeled_data/508013.PNG
#   inflating: unlabeled_data/508014.PNG
#   inflating: unlabeled_data/508015.PNG
#   inflating: unlabeled_data/508016.PNG
#   inflating: unlabeled_data/508017.PNG
#   inflating: unlabeled_data/508018.PNG
#   inflating: unlabeled_data/508019.PNG
#   inflating: unlabeled_data/508020.PNG
#   inflating: unlabeled_data/508021.PNG
#   inflating: unlabeled_data/508022.PNG
#   inflating: unlabeled_data/508023.PNG
#   inflating: unlabeled_data/508024.PNG
#   inflating: unlabeled_data/508025.PNG
#   inflating: unlabeled_data/508026.PNG
#   inflating: unlabeled_data/508027.PNG
#   inflating: unlabeled_data/508028.PNG
#   inflating: unlabeled_data/508029.PNG
#   inflating: unlabeled_data/508030.PNG
#   inflating: unlabeled_data/508031.PNG
#   inflating: unlabeled_data/508032.PNG
#   inflating: unlabeled_data/508033.PNG
#   inflating: unlabeled_data/508034.PNG
#   inflating: unlabeled_data/508035.PNG
#   inflating: unlabeled_data/508036.PNG
#   inflating: unlabeled_data/508037.PNG
#   inflating: unlabeled_data/508038.PNG
#   inflating: unlabeled_data/508039.PNG
#   inflating: unlabeled_data/508040.PNG
#   inflating: unlabeled_data/508041.PNG
#   inflating: unlabeled_data/508042.PNG
#   inflating: unlabeled_data/508043.PNG
#   inflating: unlabeled_data/508044.PNG
#   inflating: unlabeled_data/508045.PNG
#   inflating: unlabeled_data/508046.PNG
#   inflating: unlabeled_data/508047.PNG
#   inflating: unlabeled_data/508048.PNG
#   inflating: unlabeled_data/508049.PNG
#   inflating: unlabeled_data/508050.PNG
#   inflating: unlabeled_data/508051.PNG
#   inflating: unlabeled_data/508052.PNG
#   inflating: unlabeled_data/508053.PNG
#   inflating: unlabeled_data/508054.PNG
#   inflating: unlabeled_data/508055.PNG
#   inflating: unlabeled_data/508056.PNG
#   inflating: unlabeled_data/508057.PNG
#   inflating: unlabeled_data/508058.PNG
#   inflating: unlabeled_data/508059.PNG
#   inflating: unlabeled_data/508060.PNG
#   inflating: unlabeled_data/508061.PNG
#   inflating: unlabeled_data/508062.PNG
#   inflating: unlabeled_data/508063.PNG
#   inflating: unlabeled_data/508064.PNG
#   inflating: unlabeled_data/508065.PNG
#   inflating: unlabeled_data/508068.PNG
#   inflating: unlabeled_data/508069.PNG
#   inflating: unlabeled_data/508070.PNG
#   inflating: unlabeled_data/508071.PNG
#   inflating: unlabeled_data/508072.PNG
#   inflating: unlabeled_data/508073.PNG
#   inflating: unlabeled_data/508074.PNG
#   inflating: unlabeled_data/508075.PNG
#   inflating: unlabeled_data/508076.PNG
#   inflating: unlabeled_data/508077.PNG
#   inflating: unlabeled_data/508078.PNG
#   inflating: unlabeled_data/508079.PNG
#   inflating: unlabeled_data/508080.PNG
#   inflating: unlabeled_data/508081.PNG
#   inflating: unlabeled_data/508082.PNG
#   inflating: unlabeled_data/508083.PNG
#   inflating: unlabeled_data/508084.PNG
#   inflating: unlabeled_data/508085.PNG
#   inflating: unlabeled_data/508086.PNG
#   inflating: unlabeled_data/508087.PNG
#   inflating: unlabeled_data/508088.PNG
#   inflating: unlabeled_data/508089.PNG
#   inflating: unlabeled_data/508090.PNG
#   inflating: unlabeled_data/508091.PNG
#   inflating: unlabeled_data/508092.PNG
#   inflating: unlabeled_data/508093.PNG
#   inflating: unlabeled_data/508094.PNG
#   inflating: unlabeled_data/508095.PNG
#   inflating: unlabeled_data/508096.PNG
#   inflating: unlabeled_data/508097.PNG
#   inflating: unlabeled_data/508098.PNG
#   inflating: unlabeled_data/508099.PNG
#   inflating: unlabeled_data/508100.PNG
#   inflating: unlabeled_data/508101.PNG
#   inflating: unlabeled_data/508102.PNG
#   inflating: unlabeled_data/508103.PNG
#   inflating: unlabeled_data/508104.PNG
#   inflating: unlabeled_data/508105.PNG
#   inflating: unlabeled_data/508106.PNG
#   inflating: unlabeled_data/508107.PNG
#   inflating: unlabeled_data/508108.PNG
#   inflating: unlabeled_data/508109.PNG
#   inflating: unlabeled_data/508110.PNG
#   inflating: unlabeled_data/508111.PNG
#   inflating: unlabeled_data/508112.PNG
#   inflating: unlabeled_data/508113.PNG
#   inflating: unlabeled_data/508114.PNG
#   inflating: unlabeled_data/508115.PNG
#   inflating: unlabeled_data/508116.PNG
#   inflating: unlabeled_data/508117.PNG
#   inflating: unlabeled_data/508118.PNG
#   inflating: unlabeled_data/508119.PNG
#   inflating: unlabeled_data/508120.PNG
#   inflating: unlabeled_data/508121.PNG
#   inflating: unlabeled_data/508122.PNG
# ...
#   inflating: unlabeled_data/511604.PNG
#   inflating: unlabeled_data/511605.PNG
#   inflating: unlabeled_data/511606.PNG
#   inflating: unlabeled_data/511607.PNG
#   inflating: unlabeled_data/511608.PNG
#   inflating: unlabeled_data/511609.PNG
#   inflating: unlabeled_data/511610.PNG
#   inflating: unlabeled_data/511611.PNG
#   inflating: unlabeled_data/511612.PNG
#   inflating: unlabeled_data/511613.PNG
#   inflating: unlabeled_data/511614.PNG
#   inflating: unlabeled_data/511615.PNG
#   inflating: unlabeled_data/511616.PNG
#   inflating: unlabeled_data/511617.PNG
#   inflating: unlabeled_data/511618.PNG
#   inflating: unlabeled_data/511619.PNG
#   inflating: unlabeled_data/511620.PNG
#   inflating: unlabeled_data/511621.PNG
#   inflating: unlabeled_data/511622.PNG
#   inflating: unlabeled_data/511623.PNG
#   inflating: unlabeled_data/511624.PNG
#   inflating: unlabeled_data/511625.PNG
#   inflating: unlabeled_data/511626.PNG
#   inflating: unlabeled_data/511627.PNG
#   inflating: unlabeled_data/511628.PNG
#   inflating: unlabeled_data/511629.PNG
#   inflating: unlabeled_data/511630.PNG
#   inflating: unlabeled_data/511631.PNG
#   inflating: unlabeled_data/511632.PNG
#   inflating: unlabeled_data/511633.PNG
#   inflating: unlabeled_data/511634.PNG
#   inflating: unlabeled_data/511635.PNG
#   inflating: unlabeled_data/511638.PNG
#   inflating: unlabeled_data/511639.PNG
#   inflating: unlabeled_data/511640.PNG
#   inflating: unlabeled_data/511641.PNG
#   inflating: unlabeled_data/511642.PNG
#   inflating: unlabeled_data/511643.PNG
#   inflating: unlabeled_data/511644.PNG
#   inflating: unlabeled_data/511645.PNG
#   inflating: unlabeled_data/511646.PNG
#   inflating: unlabeled_data/511647.PNG
#   inflating: unlabeled_data/511648.PNG
#   inflating: unlabeled_data/511649.PNG
#   inflating: unlabeled_data/511650.PNG
#   inflating: unlabeled_data/511651.PNG
#   inflating: unlabeled_data/511652.PNG
#   inflating: unlabeled_data/511653.PNG
#   inflating: unlabeled_data/511654.PNG
#   inflating: unlabeled_data/511655.PNG
#   inflating: unlabeled_data/511656.PNG
#   inflating: unlabeled_data/511657.PNG
#   inflating: unlabeled_data/511658.PNG
#   inflating: unlabeled_data/511659.PNG
#   inflating: unlabeled_data/511660.PNG
#   inflating: unlabeled_data/511661.PNG
#   inflating: unlabeled_data/511662.PNG
#   inflating: unlabeled_data/511663.PNG
#   inflating: unlabeled_data/511664.PNG
#   inflating: unlabeled_data/511665.PNG
#   inflating: unlabeled_data/511666.PNG
#   inflating: unlabeled_data/511667.PNG
#   inflating: unlabeled_data/511668.PNG
#   inflating: unlabeled_data/511669.PNG
#   inflating: unlabeled_data/511670.PNG
#   inflating: unlabeled_data/511671.PNG
#   inflating: unlabeled_data/511672.PNG
#   inflating: unlabeled_data/511673.PNG
#   inflating: unlabeled_data/511674.PNG
#   inflating: unlabeled_data/511675.PNG
#   inflating: unlabeled_data/511676.PNG
#   inflating: unlabeled_data/511677.PNG
#   inflating: unlabeled_data/511678.PNG
#   inflating: unlabeled_data/511679.PNG
#   inflating: unlabeled_data/511680.PNG
#   inflating: unlabeled_data/511681.PNG
#   inflating: unlabeled_data/511682.PNG
#   inflating: unlabeled_data/511683.PNG
#   inflating: unlabeled_data/511684.PNG
#   inflating: unlabeled_data/511685.PNG
#   inflating: unlabeled_data/511686.PNG
#   inflating: unlabeled_data/511687.PNG
#   inflating: unlabeled_data/511688.PNG
#   inflating: unlabeled_data/511689.PNG
#   inflating: unlabeled_data/511690.PNG
#   inflating: unlabeled_data/511691.PNG
#   inflating: unlabeled_data/511692.PNG
#   inflating: unlabeled_data/511693.PNG
#   inflating: unlabeled_data/511694.PNG
#   inflating: unlabeled_data/511695.PNG
#   inflating: unlabeled_data/511696.PNG
#   inflating: unlabeled_data/511697.PNG
#   inflating: unlabeled_data/511698.PNG
#   inflating: unlabeled_data/511699.PNG
#   inflating: unlabeled_data/511700.PNG
#   inflating: unlabeled_data/511701.PNG
#   inflating: unlabeled_data/511702.PNG
#   inflating: unlabeled_data/511703.PNG
#   inflating: unlabeled_data/511704.PNG
#   inflating: unlabeled_data/511705.PNG
#   inflating: unlabeled_data/511706.PNG
#   inflating: unlabeled_data/511707.PNG
#   inflating: unlabeled_data/511708.PNG
#   inflating: unlabeled_data/511709.PNG
#   inflating: unlabeled_data/511710.PNG
#   inflating: unlabeled_data/511711.PNG
#   inflating: unlabeled_data/511712.PNG
#   inflating: unlabeled_data/511713.PNG
#   inflating: unlabeled_data/511714.PNG
#   inflating: unlabeled_data/511715.PNG
#   inflating: unlabeled_data/511716.PNG
#   inflating: unlabeled_data/511717.PNG
#   inflating: unlabeled_data/511718.PNG
#   inflating: unlabeled_data/511719.PNG
#   inflating: unlabeled_data/511720.PNG
#   inflating: unlabeled_data/511721.PNG
#   inflating: unlabeled_data/511722.PNG
#   inflating: unlabeled_data/511723.PNG
#   inflating: unlabeled_data/511724.PNG
#   inflating: unlabeled_data/511725.PNG
#   inflating: unlabeled_data/511726.PNG
#   inflating: unlabeled_data/511727.PNG
#   inflating: unlabeled_data/511728.PNG
#   inflating: unlabeled_data/511729.PNG
#   inflating: unlabeled_data/511730.PNG
#   inflating: unlabeled_data/511731.PNG
#   inflating: unlabeled_data/511732.PNG
#   inflating: unlabeled_data/511733.PNG
#   inflating: unlabeled_data/511734.PNG
#   inflating: unlabeled_data/511735.PNG
#   inflating: unlabeled_data/511736.PNG
#   inflating: unlabeled_data/511737.PNG
#   inflating: unlabeled_data/511738.PNG
#   inflating: unlabeled_data/511739.PNG
#   inflating: unlabeled_data/511740.PNG
#   inflating: unlabeled_data/511741.PNG
#   inflating: unlabeled_data/511742.PNG
#   inflating: unlabeled_data/511743.PNG
#   inflating: unlabeled_data/511744.PNG
#   inflating: unlabeled_data/511745.PNG
#   inflating: unlabeled_data/511746.PNG
#   inflating: unlabeled_data/511747.PNG
#   inflating: unlabeled_data/511748.PNG
#   inflating: unlabeled_data/511749.PNG
#   inflating: unlabeled_data/511750.PNG
#   inflating: unlabeled_data/511751.PNG
#   inflating: unlabeled_data/511752.PNG
#   inflating: unlabeled_data/511753.PNG
#   inflating: unlabeled_data/511754.PNG
#   inflating: unlabeled_data/511755.PNG
#   inflating: unlabeled_data/511756.PNG
#   inflating: unlabeled_data/511757.PNG
#   inflating: unlabeled_data/511758.PNG
#   inflating: unlabeled_data/511759.PNG
#   inflating: unlabeled_data/511760.PNG
#   inflating: unlabeled_data/511761.PNG
#   inflating: unlabeled_data/511762.PNG
#   inflating: unlabeled_data/511763.PNG
#   inflating: unlabeled_data/511764.PNG
#   inflating: unlabeled_data/511765.PNG
#   inflating: unlabeled_data/511766.PNG
#   inflating: unlabeled_data/511767.PNG
#   inflating: unlabeled_data/511768.PNG
#   inflating: unlabeled_data/511769.PNG
#   inflating: unlabeled_data/511770.PNG
#   inflating: unlabeled_data/511771.PNG
#   inflating: unlabeled_data/511772.PNG
#   inflating: unlabeled_data/511773.PNG
#   inflating: unlabeled_data/511774.PNG
#   inflating: unlabeled_data/511775.PNG
#   inflating: unlabeled_data/511776.PNG
#   inflating: unlabeled_data/511777.PNG
#   inflating: unlabeled_data/511778.PNG
#   inflating: unlabeled_data/511779.PNG
#   inflating: unlabeled_data/511780.PNG
#   inflating: unlabeled_data/511781.PNG
#   inflating: unlabeled_data/511782.PNG
#   inflating: unlabeled_data/511783.PNG
#   inflating: unlabeled_data/511784.PNG
#   inflating: unlabeled_data/511785.PNG
#   inflating: unlabeled_data/511786.PNG
#   inflating: unlabeled_data/511787.PNG
#   inflating: unlabeled_data/511788.PNG
#   inflating: unlabeled_data/511789.PNG
#   inflating: unlabeled_data/511790.PNG
#   inflating: unlabeled_data/511791.PNG
#   inflating: unlabeled_data/511792.PNG
#   inflating: unlabeled_data/511793.PNG
#   inflating: unlabeled_data/511794.PNG
#   inflating: unlabeled_data/511795.PNG
#   inflating: unlabeled_data/511796.PNG
#   inflating: unlabeled_data/511797.PNG
#   inflating: unlabeled_data/511798.PNG
#   inflating: unlabeled_data/511799.PNG
#   inflating: unlabeled_data/511800.PNG
#   inflating: unlabeled_data/511801.PNG
#   inflating: unlabeled_data/511802.PNG
#   inflating: unlabeled_data/511803.PNG
#   inflating: unlabeled_data/511804.PNG
#   inflating: unlabeled_data/511805.PNG
#   inflating: unlabeled_data/511808.PNG
#   inflating: unlabeled_data/511809.PNG
#   inflating: unlabeled_data/511810.PNG
#   inflating: unlabeled_data/511811.PNG
#   inflating: unlabeled_data/511812.PNG
#   inflating: unlabeled_data/511813.PNG
#   inflating: unlabeled_data/511814.PNG
#   inflating: unlabeled_data/511815.PNG
#   inflating: unlabeled_data/511816.PNG
#   inflating: unlabeled_data/511817.PNG
#   inflating: unlabeled_data/511818.PNG
#   inflating: unlabeled_data/511819.PNG
#   inflating: unlabeled_data/511820.PNG
#   inflating: unlabeled_data/511821.PNG
#   inflating: unlabeled_data/511822.PNG
#   inflating: unlabeled_data/511823.PNG
#   inflating: unlabeled_data/511824.PNG
#   inflating: unlabeled_data/511825.PNG
#   inflating: unlabeled_data/511826.PNG
#   inflating: unlabeled_data/511827.PNG
#   inflating: unlabeled_data/511828.PNG
#   inflating: unlabeled_data/511829.PNG
#   inflating: unlabeled_data/511830.PNG
#   inflating: unlabeled_data/511831.PNG
#   inflating: unlabeled_data/511832.PNG
#   inflating: unlabeled_data/511833.PNG
#   inflating: unlabeled_data/511834.PNG
#   inflating: unlabeled_data/511835.PNG
#   inflating: unlabeled_data/511836.PNG
#   inflating: unlabeled_data/511837.PNG
#   inflating: unlabeled_data/511838.PNG
#   inflating: unlabeled_data/511839.PNG
#   inflating: unlabeled_data/511840.PNG
#   inflating: unlabeled_data/511841.PNG
#   inflating: unlabeled_data/511842.PNG
#   inflating: unlabeled_data/511843.PNG
#   inflating: unlabeled_data/511844.PNG
#   inflating: unlabeled_data/511845.PNG
#   inflating: unlabeled_data/511846.PNG
#   inflating: unlabeled_data/511847.PNG
#   inflating: unlabeled_data/511848.PNG
#   inflating: unlabeled_data/511849.PNG
#   inflating: unlabeled_data/511850.PNG
#   inflating: unlabeled_data/511851.PNG
#   inflating: unlabeled_data/511852.PNG
#   inflating: unlabeled_data/511853.PNG
#   inflating: unlabeled_data/511854.PNG
#   inflating: unlabeled_data/511855.PNG
#   inflating: unlabeled_data/511856.PNG
#   inflating: unlabeled_data/511857.PNG
#   inflating: unlabeled_data/511858.PNG
#   inflating: unlabeled_data/511859.PNG
#   inflating: unlabeled_data/511860.PNG
#   inflating: unlabeled_data/511861.PNG
#   inflating: unlabeled_data/511862.PNG
#   inflating: unlabeled_data/511863.PNG
#   inflating: unlabeled_data/511864.PNG
#   inflating: unlabeled_data/511865.PNG
#   inflating: unlabeled_data/511866.PNG
#   inflating: unlabeled_data/511867.PNG
#   inflating: unlabeled_data/511868.PNG
#   inflating: unlabeled_data/511869.PNG
#   inflating: unlabeled_data/511870.PNG
#   inflating: unlabeled_data/511871.PNG
#   inflating: unlabeled_data/511872.PNG
#   inflating: unlabeled_data/511873.PNG
#   inflating: unlabeled_data/511874.PNG
#   inflating: unlabeled_data/511875.PNG
#   inflating: unlabeled_data/511876.PNG
#   inflating: unlabeled_data/511877.PNG
#   inflating: unlabeled_data/511878.PNG
#   inflating: unlabeled_data/511879.PNG
#   inflating: unlabeled_data/511880.PNG
#   inflating: unlabeled_data/511881.PNG
#   inflating: unlabeled_data/511882.PNG
#   inflating: unlabeled_data/511883.PNG
#   inflating: unlabeled_data/511884.PNG
#   inflating: unlabeled_data/511885.PNG
#   inflating: unlabeled_data/511886.PNG
#   inflating: unlabeled_data/511887.PNG
#   inflating: unlabeled_data/511888.PNG
#   inflating: unlabeled_data/511889.PNG
#   inflating: unlabeled_data/511890.PNG
#   inflating: unlabeled_data/511891.PNG
#   inflating: unlabeled_data/511892.PNG
#   inflating: unlabeled_data/511893.PNG
#   inflating: unlabeled_data/511894.PNG
#   inflating: unlabeled_data/511895.PNG
#   inflating: unlabeled_data/511896.PNG
#   inflating: unlabeled_data/511897.PNG
#   inflating: unlabeled_data/511898.PNG
#   inflating: unlabeled_data/511899.PNG
#   inflating: unlabeled_data/511900.PNG
#   inflating: unlabeled_data/511901.PNG
#   inflating: unlabeled_data/511902.PNG
#   inflating: unlabeled_data/511903.PNG
#   inflating: unlabeled_data/511904.PNG
#   inflating: unlabeled_data/511905.PNG
#   inflating: unlabeled_data/511906.PNG
#   inflating: unlabeled_data/511907.PNG
#   inflating: unlabeled_data/511908.PNG
#   inflating: unlabeled_data/511909.PNG
#   inflating: unlabeled_data/511910.PNG
#   inflating: unlabeled_data/511911.PNG
#   inflating: unlabeled_data/511912.PNG
#   inflating: unlabeled_data/511913.PNG
#   inflating: unlabeled_data/511914.PNG
#   inflating: unlabeled_data/511915.PNG
#   inflating: unlabeled_data/511916.PNG
#   inflating: unlabeled_data/511917.PNG
#   inflating: unlabeled_data/511918.PNG
#   inflating: unlabeled_data/511919.PNG
#   inflating: unlabeled_data/511920.PNG
#   inflating: unlabeled_data/511921.PNG
#   inflating: unlabeled_data/511922.PNG
#   inflating: unlabeled_data/511923.PNG
#   inflating: unlabeled_data/511924.PNG
#   inflating: unlabeled_data/511925.PNG
#   inflating: unlabeled_data/511926.PNG
#   inflating: unlabeled_data/511927.PNG
#   inflating: unlabeled_data/511928.PNG
#   inflating: unlabeled_data/511929.PNG
#   inflating: unlabeled_data/511930.PNG
#   inflating: unlabeled_data/511931.PNG
#   inflating: unlabeled_data/511932.PNG
#   inflating: unlabeled_data/511933.PNG
#   inflating: unlabeled_data/511934.PNG
#   inflating: unlabeled_data/511935.PNG
#   inflating: unlabeled_data/511936.PNG
#   inflating: unlabeled_data/511937.PNG
#   inflating: unlabeled_data/511938.PNG
#   inflating: unlabeled_data/511939.PNG
#   inflating: unlabeled_data/511940.PNG
#   inflating: unlabeled_data/511941.PNG
#   inflating: unlabeled_data/511942.PNG
#   inflating: unlabeled_data/511943.PNG
#   inflating: unlabeled_data/511944.PNG
#   inflating: unlabeled_data/511945.PNG
#   inflating: unlabeled_data/511946.PNG
#   inflating: unlabeled_data/511947.PNG
#   inflating: unlabeled_data/511948.PNG
#   inflating: unlabeled_data/511949.PNG
#   inflating: unlabeled_data/511950.PNG
#   inflating: unlabeled_data/511951.PNG
#   inflating: unlabeled_data/511952.PNG
#   inflating: unlabeled_data/511953.PNG
#   inflating: unlabeled_data/511954.PNG
#   inflating: unlabeled_data/511955.PNG
#   inflating: unlabeled_data/511956.PNG
#   inflating: unlabeled_data/511957.PNG
#   inflating: unlabeled_data/511958.PNG
#   inflating: unlabeled_data/511959.PNG
#   inflating: unlabeled_data/511960.PNG
#   inflating: unlabeled_data/511961.PNG
#   inflating: unlabeled_data/511962.PNG
#   inflating: unlabeled_data/511963.PNG
#   inflating: unlabeled_data/511964.PNG
#   inflating: unlabeled_data/511965.PNG
#   inflating: unlabeled_data/511966.PNG
#   inflating: unlabeled_data/511967.PNG
#   inflating: unlabeled_data/511968.PNG
#   inflating: unlabeled_data/511969.PNG
#   inflating: unlabeled_data/511970.PNG
#   inflating: unlabeled_data/511971.PNG
#   inflating: unlabeled_data/511972.PNG
#   inflating: unlabeled_data/511973.PNG
#   inflating: unlabeled_data/511974.PNG
#   inflating: unlabeled_data/511975.PNG
#   inflating: unlabeled_data/511978.PNG
#   inflating: unlabeled_data/511979.PNG
#   inflating: unlabeled_data/511980.PNG
#   inflating: unlabeled_data/511981.PNG
#   inflating: unlabeled_data/511982.PNG
#   inflating: unlabeled_data/511983.PNG
#   inflating: unlabeled_data/511984.PNG
#   inflating: unlabeled_data/511985.PNG
#   inflating: unlabeled_data/511986.PNG
#   inflating: unlabeled_data/511987.PNG
#   inflating: unlabeled_data/511988.PNG
#   inflating: unlabeled_data/511989.PNG
#   inflating: unlabeled_data/511990.PNG
#   inflating: unlabeled_data/511991.PNG
#   inflating: unlabeled_data/511992.PNG
#   inflating: unlabeled_data/511993.PNG
#   inflating: unlabeled_data/511994.PNG
#   inflating: unlabeled_data/511995.PNG
#   inflating: unlabeled_data/511996.PNG
#   inflating: unlabeled_data/511997.PNG
#   inflating: unlabeled_data/511998.PNG
#   inflating: unlabeled_data/512000.PNG

# %%
os.rename('unlabeled_data/512000.PNG', 'unlabeled_data/511999.PNG')
#os.rename('/content/unlabeled_data/512000.PNG', '/content/unlabeled_data/511999.PNG')

# %% [markdown]
# ## 1) Training a ResNet50 backbone using a slightly modified public github repo
#
# The version used in the project can be seen as a folder in the submission. main_vicreg was changed to allow training on our dataset, and hubconf.py was changed to be extra sure we are not using any pre-trained weights.
#
# (Reference https://github.com/facebookresearch/vicreg)
#
# This was explicitely stated to be allowed, as explified by the thread: https://campuswire.com/c/G55A3869E/feed/230

# %% [markdown]
# Code to download the original library:
#
#
# ```
# %%bash
#
# git clone https://github.com/facebookresearch/vicreg
# ```

# %% [markdown]
# Then, the following command is used to train a backbone with VICReg.
#
# (the backbone in submission was trained for 3 epochs with base learning rate of 0.3. The output here reflects further experimentation which was not used in our last model due to time constraints)

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 /content/vicreg/main_vicreg.py --data-dir /content/unlabeled_data --exp-dir /content/exp --arch resnet50 --epochs 10 --batch-size 256 --base-lr 0.5
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# | distributed init (rank 0): env://, gpu 0
# Namespace(arch='resnet50', base_lr=0.5, batch_size=256, cov_coeff=1.0, data_dir=PosixPath('/content/unlabeled_data'), device='cuda', dist_backend='nccl', dist_url='env://', epochs=10, exp_dir=PosixPath('/content/exp'), gpu=0, local_rank=0, log_freq_time=60, mlp='8192-8192-8192', num_workers=10, rank=0, sim_coeff=25.0, std_coeff=25.0, wd=1e-06, world_size=1)
# /content/vicreg/main_vicreg.py --local_rank=0 --data-dir /content/unlabeled_data --exp-dir /content/exp --arch resnet50 --epochs 10 --batch-size 256 --base-lr 0.5
# {"epoch": 9, "step": 19392, "loss": 19.42539405822754, "time": 15955, "lr": 0.4848}
# {"epoch": 9, "step": 19465, "loss": 19.407947540283203, "time": 16015, "lr": 0.486625}
# {"epoch": 9, "step": 19542, "loss": 19.56814193725586, "time": 16076, "lr": 0.48855}
# {"epoch": 9, "step": 19614, "loss": 19.44521141052246, "time": 16136, "lr": 0.49035}
# {"epoch": 9, "step": 19693, "loss": 19.40750503540039, "time": 16199, "lr": 0.492325}
# {"epoch": 9, "step": 19772, "loss": 19.404224395751953, "time": 16260, "lr": 0.4943}
# {"epoch": 9, "step": 19843, "loss": 19.392112731933594, "time": 16320, "lr": 0.496075}
# {"epoch": 9, "step": 19921, "loss": 19.46755599975586, "time": 16381, "lr": 0.498025}

# %% [markdown]
# # 2) Custom Model Building and Training
#
# (Not used in final version of the backbone, but was used in earlier versions with lower precision)

# %% [markdown]
# ### 2.1>1) Directly use classes from eval.py here to ensure compatibility

# %%
class UnlabeledDataset(torch.utils.data.Dataset):
    def __init__(self, root, transform):
        r"""
        Args:
            root: Location of the dataset folder, usually it is /unlabeled
            transform: the transform you want to applied to the images.
        """
        self.transform = transform
        self.image_dir = root
        self.num_images = len(os.listdir(self.image_dir))

    def __len__(self):
        return self.num_images

    def __getitem__(self, idx):
        # the idx of unlabeled image is from 0
        with open(os.path.join(self.image_dir, f"{idx}.PNG"), "rb") as f: 
            img = Image.open(f).convert("RGB")

        return self.transform(img)

# %%
device = torch.device("cuda") 
print(device)
# Out:
# cuda

# %% [markdown]
# ### 2.1.2) Make the necessary definitions

# %%
UNLABELED_DATASET_PATH = '/content/unlabeled_data' 
BATCH_SIZE = 64

"""
def unlabeled_transform(x):
    return torchvision.transforms.functional.to_tensor(x)
"""

unlabeled_dataset = UnlabeledDataset(
    root=UNLABELED_DATASET_PATH,
    transform=transforms, #aug.TrainTransform()
)

unlabeled_loader = torch.utils.data.DataLoader(
    unlabeled_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
)

# %% [markdown]
# ### 2.2) Defining data agumentation and loss functions

# %%
import torch
import torchvision.transforms as T

# Taken from online page, source: https://github.com/Spijkervet/SimCLR/blob/master/simclr/modules/transformations/simclr.py
# + changed to match the augemntation described in VICReg paper better
class Augment:
   """
   A stochastic data augmentation module
   Transforms any given data example randomly
   resulting in two correlated views of the same example,
   denoted x ̃i and x ̃j, which we consider as a positive pair.
   """

   def __init__(self, img_size, s=1):
       color_jitter = T.ColorJitter(
           0.4 * s, 0.4 * s, 0.2 * s, 0.1 * s
       )
       # 10% of the image
       blur = T.GaussianBlur(23) #T.GaussianBlur((3, 3), (0.1, 2.0))

       self.train_transform = torch.nn.Sequential(
           T.RandomResizedCrop(size=img_size),
           T.RandomHorizontalFlip(p=0.5),  # with 0.5 probability
           T.RandomApply([color_jitter], p=0.8),
           T.RandomGrayscale(p=0.2),
           T.RandomApply([blur], p=0.5),
           #T.RandomSolarize(threshold=192.0, p=0.1),
           T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
       )

   def __call__(self, x):
       return (self.train_transform(x), self.train_transform(x))
# Out:
# '\nimport torch\nimport torchvision.transforms as T\n\n# Taken from online page, will find source for reference\n# + changed with the augemntation described in VICReg paper\nclass Augment:\n   """\n   A stochastic data augmentation module\n   Transforms any given data example randomly\n   resulting in two correlated views of the same example,\n   denoted x ̃i and x ̃j, which we consider as a positive pair.\n   """\n\n   def __init__(self, img_size, s=1):\n       color_jitter = T.ColorJitter(\n           0.4 * s, 0.4 * s, 0.2 * s, 0.1 * s\n       )\n       # 10% of the image\n       blur = T.GaussianBlur(23) #T.GaussianBlur((3, 3), (0.1, 2.0))\n\n       self.train_transform = torch.nn.Sequential(\n           T.RandomResizedCrop(size=img_size),\n           T.RandomHorizontalFlip(p=0.5),  # with 0.5 probability\n           T.RandomApply([color_jitter], p=0.8),\n           T.RandomGrayscale(p=0.2),\n           T.RandomApply([blur], p=0.5),\n           #T.RandomSolarize(threshold=192.0, p=0.1),\n           T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])\n       )\n\n   def __call__(self, x):\n       return (self.train_transform(x), self.train_transform(x))\n'

# %%
#The VICReg loss function
#Used source: https://github.com/untitled-ai/self_supervised/blob/7a43c4ae2c2d42cb68e688c8fec86948c9547e72/moco.py
#Constants from paper: https://openreview.net/pdf?id=xm6YD62D1Ub
def VICReg_loss(z_a, z_b):
        assert z_a.shape == z_b.shape and len(z_a.shape) == 2
        
        variance_loss_epsilon = 0.0001
        
        # invariance loss
        loss_inv = F.mse_loss(z_a, z_b)

        # variance loss
        std_z_a = torch.sqrt(z_a.var(dim=0) + variance_loss_epsilon)
        std_z_b = torch.sqrt(z_b.var(dim=0) + variance_loss_epsilon)
        loss_v_a = torch.mean(F.relu(1 - std_z_a))
        loss_v_b = torch.mean(F.relu(1 - std_z_b))
        loss_var = loss_v_a + loss_v_b

        # covariance loss
        N, D = z_a.shape
        z_a = z_a - z_a.mean(dim=0)
        z_b = z_b - z_b.mean(dim=0)
        cov_z_a = ((z_a.T @ z_a) / (N - 1)).square()  # DxD
        cov_z_b = ((z_b.T @ z_b) / (N - 1)).square()  # DxD
        loss_c_a = (cov_z_a.sum() - cov_z_a.diagonal().sum()) / D
        loss_c_b = (cov_z_b.sum() - cov_z_b.diagonal().sum()) / D
        loss_cov = loss_c_a + loss_c_b

        weighted_inv = loss_inv * 25 #invariance_loss_weight
        weighted_var = loss_var * 25 #variance_loss_weight
        weighted_cov = loss_cov * 1 #covariance_loss_weight

        loss = weighted_inv + weighted_var + weighted_cov

        return loss

# %% [markdown]
# ### 2.3) Building The Self-Supervised Architecture

# %% [markdown]
# Chosen regularization method: Information Maximization

# %%
class SSL_NN(nn.Module):
    def __init__(self, backbone, poller, representation_size, expanded_size):
        super().__init__()
        self.representation_size = representation_size
        self.layer_size = expanded_size
        self.backbone = backbone
        self.poller = poller
        self.expander = nn.Sequential(  nn.Linear(in_features=self.representation_size, out_features=self.layer_size),
                                        nn.BatchNorm1d(self.layer_size),
                                        nn.ReLU(),
                                        nn.Linear(in_features=self.layer_size, out_features=self.layer_size),
                                        nn.BatchNorm1d(self.layer_size),
                                        nn.ReLU(),
                                        nn.Linear(in_features=self.layer_size, out_features=self.layer_size),
                                        nn.BatchNorm1d(self.layer_size))

    def forward(self, x):
        x = self.backbone(x)
        #x = self.poller(x)
        x = torch.squeeze(x).view(-1, self.representation_size)
        x = self.expander(x)
        return x

# %%
resnet_model = torchvision.models.resnet50(pretrained=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
encoder = nn.Sequential(*list(resnet_model.children())[:8]) #(does not includes avg pooling) #Output dimension: 2048

# %%
avg_pool = list(resnet_model.children())[8]

# %% [markdown]
# Now, we also need an expander for our architecture:

# %%
#Using VICReg for regularization
#References: https://generallyintelligent.ai/open-source/2022-04-21-vicreg/
#https://www.arxiv-vanity.com/papers/2105.04906/
#Min paper: https://arxiv.org/pdf/2105.04906.pdf

repr_size = 2048
expanded_size = 8192
ssl_model = SSL_NN(encoder, avg_pool, repr_size, expanded_size)

# %%
#ssl_model

# %% [markdown]
# ### 2.4) Training the backbone network

# %%
from collections import defaultdict, deque

augmenter = Augment(224)

def get_backbone_loss(model, batch, criterion, device):
    # Implement forward pass and loss calculation for one batch.
    # Remember to move the batch to device.
    # 
    # Return loss for the batch (Tensor)
    data = batch
    data = data.to(device)
    
    X1, X2 = augmenter(data)
    #To see the inouts side by side:
    #plt.imshow(  X1[0].cpu().permute(1, 2, 0),   )
    #plt.show()
    #plt.imshow(  X2[0].cpu().permute(1, 2, 0)  )
    #plt.show()
    Z1 = model(X1)
    Z2 = model(X2)
    batch_loss = criterion(Z1, Z2)

    return batch_loss

def step(loss, optimizer):
    # Implement backward pass and update.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

from tqdm.notebook import tqdm
    
def backbone_train(model, data_loader, criterion, optimizer, device, N_EPOCHS = 5):
    model.to(device)
    
    train_losses = []
    
    pbar = tqdm(range(N_EPOCHS))
    for i in pbar:
        model.train()
        
        total_train_loss = 0
        
        i = 0
        for batch in tqdm(data_loader):
            try:
              loss = get_backbone_loss(model, batch, criterion, device)
              step(loss, optimizer)
              total_train_loss += loss.item()
              i += 1
              #print("Batch: ", i, " | Loss:" , loss.item())
              if(i % 20 == 0):
                print("Batch: ", i, " | Loss:" , loss.item())
            except:
                print("An exception occurred in Batch: ", i)
        
        mean_train_loss = total_train_loss / 8000 #hardcoded number of batches, may change by batch size
        print(mean_train_loss)
        train_losses.append(mean_train_loss)
        pbar.set_postfix({'train_loss': mean_train_loss})#
        
    optimizer.zero_grad() #leave gradients at zero after training, just as a safety

# %%
criterion = VICReg_loss
optimizer = torch.optim.SGD(ssl_model.parameters(), lr=0.0001, momentum=0.9)

backbone_train(ssl_model, unlabeled_loader, criterion,optimizer, device, 5)

# %%
#ssl_model

# %%
torch.save(ssl_model, '/content/gdrive/MyDrive/proj/ssl_model_new2.pt')

# %%
backbone = ssl_model.backbone

# %%
torch.save(backbone, '/content/gdrive/proj/backbone_model.pt')

# %%
#backbone

# %%
#ssl_model2 = torch.load("/content/gdrive/MyDrive/proj/ssl_model_new.pt")

# %%
#criterion = VICReg_loss
#optimizer = torch.optim.SGD(ssl_model2.parameters(), lr=0.00001, momentum=0.9)

#backbone_train(ssl_model2, unlabeled_loader, criterion, optimizer, device, 5)
